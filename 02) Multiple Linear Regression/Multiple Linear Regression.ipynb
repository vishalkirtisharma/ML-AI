# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df['State'].nunique()
# Out:
# 3

# %%
df =pd.concat([df, pd.get_dummies(df['State'],drop_first=True)],axis=1).drop('State',axis=1)

# %%
X = df.drop('Profit',axis=1)
y = df['Profit']

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# Profit             0
# Florida            0
# New York           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
# Calculate and print Mean Absolute Error (MAE)
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, predictions))

# Calculate and print Mean Squared Error (MSE)
print("Mean Squared Error (MSE):", mean_squared_error(y_test, predictions))

# Calculate and print Root Mean Squared Error (RMSE) - standard practice
print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error (MAE): 7068.317931660087
# Mean Squared Error (MSE): 83628721.14419533
# Root Mean Squared Error (RMSE): 9144.874036540652

# %%
np.set_printoptions(precision=2)

print(np.concatenate((
                      predictions.reshape(len(predictions),1),
                      y_test.values.reshape(len(y_test),1)
                      ),1))
# Out:
# [[ 86894.76  89949.14]
#  [153481.03 132602.65]
#  [119836.84 111313.02]
#  [ 98459.9   97427.84]
#  [118555.74 110352.25]
#  [189726.   191792.06]
#  [114295.31 105733.54]
#  [ 61551.3   49490.75]
#  [ 70236.86  71498.49]
#  [ 47600.77  42559.73]]
